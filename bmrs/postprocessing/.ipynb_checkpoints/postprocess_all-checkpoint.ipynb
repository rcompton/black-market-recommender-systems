# %%
import pandas as pd
import dateutil
import os
import ast

import logging
FORMAT = '%(asctime)-15s %(levelname)-6s %(message)s'
DATE_FORMAT = '%b %d %H:%M:%S'
formatter = logging.Formatter(fmt=FORMAT, datefmt=DATE_FORMAT)
handler = logging.StreamHandler()
handler.setFormatter(formatter)
logger = logging.getLogger(__name__)
logger.addHandler(handler)
logger.setLevel(logging.INFO)

# %%
META_CATS = ['Other','Drugs','Services', 'Custom Listings', 'DRUGS & MORE','other service','other drugs','others']
META_CATS = [s.lower() for s in META_CATS]

# %%
def load_agora():
    DATA_DIR='/home/aahu/Dropbox/black-market-recommender-systems/data/agora/'
    l=[]
    for fname in os.listdir(DATA_DIR):
        if fname.endswith('.tsv'):
            df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
            l.append(df0)
    df = pd.concat(l)
    logger.info(df.columns)
    logger.info(df.shape)
    return df

# %%
def load_pandora():
    DATA_DIR='/home/aahu/Dropbox/black-market-recommender-systems/data/pandora/'
    l=[]
    for fname in os.listdir(DATA_DIR):
        if fname.endswith('.tsv'):
            try:
                df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
                l.append(df0)
            except ValueError:
                #logger.exception('no data')
                pass
    df = pd.concat(l)
    logger.info(df.columns)
    logger.info(df.shape)
    return df

# %%
def load_cloudnine():
    DATA_DIR='/home/aahu/Dropbox/black-market-recommender-systems/data/cloudnine/'
    l=[]
    for fname in os.listdir(DATA_DIR):
        if fname.endswith('.tsv'):
            try:
                df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
                l.append(df0)
            except ValueError:
                logger.exception('no data')
                pass
    df = pd.concat(l)
    logger.info(df.columns)
    logger.info(df.shape)
    
    #be consistent
    df.rename(columns={'scraped_date':'scrape_date'}, inplace=True)
    df['cat'] = df['cat'].map(lambda x: ast.literal_eval(x))
    df['category'] = df['cat'].map(lambda x: x[-1])
    
    return df

# %%
def load_hydra():
    DATA_DIR='/home/aahu/Dropbox/black-market-recommender-systems/data/hydra/'
    l=[]
    for fname in os.listdir(DATA_DIR):
        if fname.endswith('.tsv'):
            try:
                df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
                l.append(df0)
            except ValueError:
                logger.exception('no data')
                pass
    df = pd.concat(l)
    logger.info(df.columns)
    logger.info(df.shape)
    
    #be consistent
    df.rename(columns={'scraped_date':'scrape_date'}, inplace=True)
    df['cat'] = df['category'].map(lambda x: ast.literal_eval(x))
    df['category'] = df['cat'].map(lambda x: x[-1])
    
    return df

# %%
def load_evolution():
    DATA_DIR='/home/aahu/Dropbox/black-market-recommender-systems/data/evolution/'
    l=[]
    for fname in os.listdir(DATA_DIR):
        if fname.endswith('.tsv'):
            try:
                df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
                l.append(df0)
            except ValueError:
                logger.exception('no data')
                pass
    df = pd.concat(l)
    logger.info(df.columns)
    logger.info(df.shape)
    
    #be consistent
    #df.rename(columns={'scraped_date':'scrape_date'}, inplace=True)
    #df['cat'] = df['category'].map(lambda x: ast.literal_eval(x))
    #df['category'] = df['cat'].map(lambda x: x[-1])
    
    return df

# %%
def postprocess(df):
    """
    standardized postprocessing
    """
    #normalize
    df['category'] = df['category'].map(lambda x:x.lower())
    
    #discard meta-categories
    df = df[df['category'].map(lambda x:x not in META_CATS)]
    logger.info(df.shape)
    
    #discard non-string categories
    def isfloat(value):
        try:
            float(value)
            return True
        except ValueError:
            return False
    df = df[df['category'].map(lambda x:not isfloat(x))]
    
    return df

# %%
def load_silkroad2():
    DATA_DIR='/home/aahu/Dropbox/black-market-recommender-systems/data/silkroad2/'
    l=[]
    for fname in os.listdir(DATA_DIR):
        if fname.endswith('.tsv'):
            try:
                df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
                l.append(df0)
            except ValueError:
                logger.exception('no data')
                pass
    df = pd.concat(l)
    logger.info(df.columns)
    logger.info(df.shape)
    
    #be consistent
    df['cat'] = df['category'].map(lambda x: x.split('-'))
    df['category'] = df['cat'].map(lambda x: x[-1])
    
    return df

sr = load_silkroad2()
sr
# Out:
# May 20 21:29:41 INFO   Index(['category', 'listing', 'price_btc', 'scrape_date', 'ships_from', 'ships_to', 'vendor'], dtype='object')
# INFO:__main__:Index(['category', 'listing', 'price_btc', 'scrape_date', 'ships_from', 'ships_to', 'vendor'], dtype='object')
# May 20 21:29:41 INFO   (663912, 7)
# INFO:__main__:(663912, 7)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ee6480994315> in <module>()
#      20     return df
#      21
# ---> 22 sr = load_silkroad2()
#      23 sr
#
# <ipython-input-7-ee6480994315> in load_silkroad2()
#      15
#      16     #be consistent
# ---> 17     df['cat'] = df['category'].map(lambda x: ast.literal_eval(x))
#      18     df['category'] = df['cat'].map(lambda x: x[-1])
#      19
#
# /usr/local/lib/python3.4/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    2013                                      index=self.index).__finalize__(self)
#    2014         else:
# -> 2015             mapped = map_f(values, arg)
#    2016             return self._constructor(mapped,
#    2017                                      index=self.index).__finalize__(self)
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:57158)()
#
# <ipython-input-7-ee6480994315> in <lambda>(x)
#      15
#      16     #be consistent
# ---> 17     df['cat'] = df['category'].map(lambda x: ast.literal_eval(x))
#      18     df['category'] = df['cat'].map(lambda x: x[-1])
#      19
#
# /usr/lib/python3.4/ast.py in literal_eval(node_or_string)
#      82                 return left - right
#      83         raise ValueError('malformed node or string: ' + repr(node))
# ---> 84     return _convert(node_or_string)
#      85
#      86
#
# /usr/lib/python3.4/ast.py in _convert(node)
#      81             else:
#      82                 return left - right
# ---> 83         raise ValueError('malformed node or string: ' + repr(node))
#      84     return _convert(node_or_string)
#      85
#
# ValueError: malformed node or string: <_ast.BinOp object at 0x7f55aa712a90>

# %%
# cn = load_cloudnine()
# cn = postprocess(cn)
# cn.to_csv('/home/aahu/Dropbox/black-market-recommender-systems/data/cloudnine.tsv',sep='\t',index=False)

# ag = load_agora()
# ag = postprocess(ag)
# ag.to_csv('/home/aahu/Dropbox/black-market-recommender-systems/data/agora.tsv',sep='\t',index=False)

#pa = load_pandora()
#pa = postprocess(pa)
#pa.to_csv('/home/aahu/Dropbox/black-market-recommender-systems/data/pandora.tsv',sep='\t',index=False)

#hy = load_hydra()
#hy = postprocess(hy)
#hy.to_csv('/home/aahu/Dropbox/black-market-recommender-systems/data/hydra.tsv',sep='\t',index=False)

# ev = load_evolution()
# ev = postprocess(ev)
# ev.to_csv('/home/aahu/Dropbox/black-market-recommender-systems/data/evolution.tsv',sep='\t',index=False)

sr2 = load_silkroad2()
sr2 = postprocess(sr2)
sr2.to_csv('/home/aahu/Dropbox/black-market-recommender-systems/data/silkroad2.tsv',sep='\t',index=False)
# Out:
# May 18 18:50:45 INFO   Index(['category', 'listing', 'scrape_date', 'vendor'], dtype='object')
# INFO:__main__:Index(['category', 'listing', 'scrape_date', 'vendor'], dtype='object')
# May 18 18:50:45 INFO   (3702353, 4)
# INFO:__main__:(3702353, 4)
# May 18 18:50:48 INFO   (3001716, 4)
# INFO:__main__:(3001716, 4)

# %%
ev
# Out:
#          category                                            listing  \
# 0      stimulants  Welcome back, gwern   0 0 0 BTC 0.0000     Hom...
# 1      stimulants                                                NaN
# 2      stimulants                                                NaN
# 3      stimulants                                                NaN
# 4      stimulants                                                NaN
# 5      stimulants                                                NaN
# 6      stimulants                                                NaN
# 7      stimulants                                                NaN
# 8      stimulants                                                NaN
# 9      stimulants                                                NaN
# 10     stimulants                                                NaN
# 11     stimulants                                                NaN
# 12     stimulants                                                NaN
# 13     stimulants                                                NaN
# 14     stimulants                                                NaN
# 15     stimulants                                                NaN
# 16     stimulants                                                NaN
# 17     stimulants                                                NaN
# 18     stimulants                                                NaN
# 19     stimulants                                                NaN
# 20     stimulants                                                NaN
# 21     stimulants                                                NaN
# 22     stimulants                                                NaN
# 23     stimulants                                                NaN
# 24     stimulants                                                NaN
# 25     stimulants                                                NaN
# 26     stimulants                                                NaN
# 27     stimulants                                                NaN
# 28     stimulants                                                NaN
# 29     stimulants                                                NaN
# ...           ...                                                ...
# 27110     hacking  [METHOD #1] eBay - How I have made 100's of do...
# 27111     hacking  *UPDATED* Wanna BIG list of the Top 100 Darkne...
# 27112     hacking  Word Exploit | Change .EXE to .DOC - Word & EX...
# 27113     hacking                                  New eBay Identity
# 27114     hacking                   Highly profitable Business ideas
# 27115     hacking         [ANDROID] Phone vip72 SOCKS + TOR Tutorial
# 27116     hacking                                      php web shell
# 27117     hacking                                 SNIFF WITH ANDROID
# 27118     hacking                        DDoS Attack - A life lesson
# 27119     hacking  Android Remote Administration Tool  (RAT) Setu...
# 27120     hacking  How to Spoof DNS on a LAN to Redirect Traffic ...
# 27121     hacking                           Hacking Secrets Revealed
# 27122     hacking       How to find someone’s IP address on Facebook
# 27123     hacking               How to hack MSN and HOTMAIL accounts
# 27124  ammunition                          Ammunition - .22LR Rounds
# 27125  ammunition          cartouche 7,65 x 17 mm Browning (.32 ACP)
# 27126  ammunition        7,62x39 mm, AK47/SKS ammunition, bag of 100
# 27127  ammunition           Rottweil 16/67,5 Kaliber. (7,4mm) 15pcs.
# 27128  ammunition           Rottweil 16/67,5 Kaliber. (3,5mm) 30pcs.
# 27129  ammunition  9x19 mm Luger - SUBSONIC Hollowpoints/JHP, Mag...
# 27130  ammunition                       cartouche 9x19 mm Parabellum
# 27131  ammunition                                  cartouche .45 ACP
# 27132  ammunition                           cartouche .22 Long Rifle
# 27133  ammunition                              cartouche .38 Special
# 27134  ammunition                              cartouche .357 Magnum
# 27135  ammunition  Bio-Hazard Gas Mask!!! Army Grade!!Protect you...
# 27136  ammunition         .40 1000 Rounds Smith and wesson Remington
# 27137  ammunition                        45 ACP 100 rounds Remington
# 27138  ammunition                             45 ACP 1000 rounds PMC
# 27139  ammunition                                 CUstom for Gravano
#
#       scrape_date            vendor
# 0      2014-07-21             gwern
# 1      2014-07-21      NORWEGIANcom
# 2      2014-07-21           drzheng
# 3      2014-07-21           drzheng
# 4      2014-07-21       godfatherNL
# 5      2014-07-21       godfatherNL
# 6      2014-07-21       godfatherNL
# 7      2014-07-21       spencerhill
# 8      2014-07-21             Zable
# 9      2014-07-21             Zable
# 10     2014-07-21             Zable
# 11     2014-07-21             Zable
# 12     2014-07-21       godfatherNL
# 13     2014-07-21       godfatherNL
# 14     2014-07-21         SheepShop
# 15     2014-07-21         SheepShop
# 16     2014-07-21         SheepShop
# 17     2014-07-21         SheepShop
# 18     2014-07-21         SheepShop
# 19     2014-07-21  AmsterdamConnect
# 20     2014-07-21  AmsterdamConnect
# 21     2014-07-21        DarkVendor
# 22     2014-07-21        DarkVendor
# 23     2014-07-21        DarkVendor
# 24     2014-07-21        DarkVendor
# 25     2014-07-21        DarkVendor
# 26     2014-07-21        DarkVendor
# 27     2014-07-21      MeyerLansky2
# 28     2014-07-21      MeyerLansky2
# 29     2014-07-21      MeyerLansky2
# ...           ...               ...
# 27110  2015-01-08          Cyberzen
# 27111  2015-01-08        DrFeelG00d
# 27112  2015-01-08        Michael555
# 27113  2015-01-08          Cyberzen
# 27114  2015-01-08          Cyberzen
# 27115  2015-01-08          Cyberzen
# 27116  2015-01-08              Code
# 27117  2015-01-08              fake
# 27118  2015-01-08         BlackDuke
# 27119  2015-01-08         BlackDuke
# 27120  2015-01-08         BlackDuke
# 27121  2015-01-08           etimbuk
# 27122  2015-01-08              fake
# 27123  2015-01-08           etimbuk
# 27124  2015-01-08           AUsTORe
# 27125  2015-01-08         projeccao
# 27126  2015-01-08     ErichHartmann
# 27127  2015-01-08          Vintorez
# 27128  2015-01-08          Vintorez
# 27129  2015-01-08     ErichHartmann
# 27130  2015-01-08         projeccao
# 27131  2015-01-08         projeccao
# 27132  2015-01-08         projeccao
# 27133  2015-01-08         projeccao
# 27134  2015-01-08         projeccao
# 27135  2015-01-08         herostats
# 27136  2015-01-08        pillpusher
# 27137  2015-01-08        pillpusher
# 27138  2015-01-08        pillpusher
# 27139  2015-01-08        dosensuppe
#
# [3001716 rows x 4 columns]

# %%
ev['vendor'].value_counts()
# Out:
# fake                113056
# rc4me                42827
# need4weed            42588
# profesorhouse        37186
# gwern                35980
# RepAAA               35560
# optiman              34522
# sexyhomer            30600
# Magicalthings123     28045
# FoxyGirl             23205
# DrPlatypus           21013
# etimbuk              20863
# cerberus             20190
# theben               19920
# AlbertHeijn          18801
# ...
# fraudster           1
# artash              1
# EVERYTHING_CHEAP    1
# tornado888          1
# ViBE                1
# firepower           1
# franktors           1
# Kastell             1
# ambra               1
# 5cent               1
# DonkeySausage       1
# freshvybz           1
# Bossen              1
# TheDruMonSer        1
# thecornershop       1
# Length: 4139, dtype: int64
