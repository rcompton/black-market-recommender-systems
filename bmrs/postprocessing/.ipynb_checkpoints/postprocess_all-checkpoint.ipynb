# %%
import pandas as pd
import dateutil
import os
import ast

import logging
FORMAT = '%(asctime)-15s %(levelname)-6s %(message)s'
DATE_FORMAT = '%b %d %H:%M:%S'
formatter = logging.Formatter(fmt=FORMAT, datefmt=DATE_FORMAT)
handler = logging.StreamHandler()
handler.setFormatter(formatter)
logger = logging.getLogger(__name__)
logger.addHandler(handler)
logger.setLevel(logging.INFO)

# %%
META_CATS = ['Other','Drugs','Services', 'Custom Listings', 'DRUGS & MORE','other service','other drugs','others']
META_CATS = [s.lower() for s in META_CATS]

# %%
def load_agora():
    DATA_DIR='/home/aahu/Dropbox/black-market-recommender-systems/data/agora/'
    l=[]
    for fname in os.listdir(DATA_DIR):
        if fname.endswith('.tsv'):
            df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
            l.append(df0)
    df = pd.concat(l)
    logger.info(df.columns)
    logger.info(df.shape)
    return df

# %%
def load_pandora():
    DATA_DIR='/home/aahu/Dropbox/black-market-recommender-systems/data/pandora/'
    l=[]
    for fname in os.listdir(DATA_DIR):
        if fname.endswith('.tsv'):
            try:
                df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
                l.append(df0)
            except ValueError:
                #logger.exception('no data')
                pass
    df = pd.concat(l)
    logger.info(df.columns)
    logger.info(df.shape)
    return df

# %%
def load_cloudnine():
    DATA_DIR='/home/aahu/Dropbox/black-market-recommender-systems/data/cloudnine/'
    l=[]
    for fname in os.listdir(DATA_DIR):
        if fname.endswith('.tsv'):
            try:
                df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
                l.append(df0)
            except ValueError:
                logger.exception('no data')
                pass
    df = pd.concat(l)
    logger.info(df.columns)
    logger.info(df.shape)
    
    #be consistent
    df.rename(columns={'scraped_date':'scrape_date'}, inplace=True)
    df['cat'] = df['cat'].map(lambda x: ast.literal_eval(x))
    df['category'] = df['cat'].map(lambda x: x[-1])
    
    return df

# %%
def load_hydra():
    DATA_DIR='/home/aahu/Dropbox/black-market-recommender-systems/data/hydra/'
    l=[]
    for fname in os.listdir(DATA_DIR):
        if fname.endswith('.tsv'):
            try:
                df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
                l.append(df0)
            except ValueError:
                logger.exception('no data')
                pass
    df = pd.concat(l)
    logger.info(df.columns)
    logger.info(df.shape)
    
    #be consistent
    df.rename(columns={'scraped_date':'scrape_date'}, inplace=True)
    df['cat'] = df['category'].map(lambda x: ast.literal_eval(x))
    df['category'] = df['cat'].map(lambda x: x[-1])
    
    return df
# Out:
# May 17 00:17:59 ERROR  no data
# Traceback (most recent call last):
#   File "<ipython-input-13-ce57e3d15e45>", line 7, in load_hydra
#     df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
#   File "/usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py", line 465, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py", line 241, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py", line 557, in __init__
#     self._make_engine(self.engine)
#   File "/usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py", line 694, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py", line 1061, in __init__
#     self._reader = _parser.TextReader(src, **kwds)
#   File "pandas/parser.pyx", line 512, in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4792)
# ValueError: No columns to parse from file
# ERROR:__main__:no data
# Traceback (most recent call last):
#   File "<ipython-input-13-ce57e3d15e45>", line 7, in load_hydra
#     df0 = pd.read_csv(os.path.join(DATA_DIR,fname), sep='\t', parse_dates=['scrape_date'])
#   File "/usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py", line 465, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py", line 241, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py", line 557, in __init__
#     self._make_engine(self.engine)
#   File "/usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py", line 694, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/usr/local/lib/python3.4/dist-packages/pandas/io/parsers.py", line 1061, in __init__
#     self._reader = _parser.TextReader(src, **kwds)
#   File "pandas/parser.pyx", line 512, in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4792)
# ValueError: No columns to parse from file
# May 17 00:17:59 INFO   Index(['category', 'listing', 'price_usd', 'scrape_date', 'ships_from', 'ships_to', 'vendor'], dtype='object')
# INFO:__main__:Index(['category', 'listing', 'price_usd', 'scrape_date', 'ships_from', 'ships_to', 'vendor'], dtype='object')
# May 17 00:17:59 INFO   (17353, 7)
# INFO:__main__:(17353, 7)
#      category  listing price_usd scrape_date     ships_from        ships_to  \
# 0      Heroin      NaN   $825.00  2014-10-24  United States       Worldwide
# 1      Heroin      NaN   $150.00  2014-10-24  United States       Worldwide
# 2      Heroin      NaN    $45.00  2014-10-24  United States       Worldwide
# 3      Heroin      NaN    $45.00  2014-10-24  United States       Worldwide
# 4      Heroin      NaN  $3200.00  2014-10-24          China       Worldwide
# 5      Heroin      NaN   $800.00  2014-10-24          China       Worldwide
# 6      Heroin      NaN   $600.00  2014-10-24          China       Worldwide
# 7      Heroin      NaN   $300.00  2014-10-24          China       Worldwide
# 8      Heroin      NaN   $160.00  2014-10-24          China       Worldwide
# 9      Heroin      NaN    $25.00  2014-10-24          China       Worldwide
# 10    Erotica      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 11    Erotica      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 12    Erotica      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 13    Erotica      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 14    Erotica      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 15    Erotica      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 16    Erotica      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 17    Erotica      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 18    Erotica      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 19    Erotica      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 20   Software      NaN    $40.00  2014-10-24      Worldwide       Worldwide
# 21   Software      NaN    $50.00  2014-10-24      Worldwide       Worldwide
# 22   Software      NaN    $50.00  2014-10-24     Undeclared       Worldwide
# 23   Software      NaN     $5.00  2014-10-24      Worldwide       Worldwide
# 24   Software      NaN   $300.00  2014-10-24      Worldwide       Worldwide
# 25   Software      NaN    $80.00  2014-10-24      Worldwide       Worldwide
# 26   Software      NaN   $120.00  2014-10-24      Worldwide       Worldwide
# 27   Software      NaN    $60.00  2014-10-24      Worldwide       Worldwide
# 28   Software      NaN    $10.00  2014-10-24      Worldwide       Worldwide
# 29   Software      NaN    $60.00  2014-10-24  United States       Worldwide
# ..        ...      ...       ...         ...            ...             ...
# 911   Cocaine      NaN   $489.00  2014-08-10      Worldwide       Worldwide
# 912   Cocaine      NaN   $350.00  2014-08-10      Worldwide       Worldwide
# 913   Cocaine      NaN   $274.00  2014-08-10      Worldwide       Worldwide
# 914   Cocaine      NaN   $115.00  2014-08-10      Worldwide       Worldwide
# 915   Cocaine      NaN  $1500.00  2014-08-10  United States       Worldwide
# 916   Cocaine      NaN   $840.00  2014-08-10  United States       Worldwide
# 917   Cocaine      NaN   $490.00  2014-08-10      Worldwide   United States
# 918   Cocaine      NaN   $270.00  2014-08-10  United States       Worldwide
# 919   Cocaine      NaN   $128.00  2014-08-10  United States       Worldwide
# 920   Cocaine      NaN    $75.00  2014-08-10  United States       Worldwide
# 921      Weed      NaN   $112.50  2014-08-10    Netherlands  European union
# 922      Weed      NaN   $135.00  2014-08-10    Netherlands  European union
# 923      Weed      NaN    $12.00  2014-08-10        Denmark  European union
# 924      Weed      NaN  $2900.00  2014-08-10  United States   United States
# 925      Weed      NaN  $1500.00  2014-08-10  United States   United States
# 926      Weed      NaN   $800.00  2014-08-10  United States   United States
# 927      Weed      NaN   $430.00  2014-08-10  United States   United States
# 928      Weed      NaN   $230.00  2014-08-10  United States   United States
# 929      Weed      NaN    $69.50  2014-08-10      Worldwide       Worldwide
# 930      Weed      NaN    $39.50  2014-08-10      Worldwide       Worldwide
# 931   Erotica      NaN     $5.00  2014-08-10      Worldwide       Worldwide
# 932   Erotica      NaN     $5.00  2014-08-10      Worldwide       Worldwide
# 933   Erotica      NaN     $5.00  2014-08-10      Worldwide       Worldwide
# 934   Erotica      NaN     $5.00  2014-08-10      Worldwide       Worldwide
# 935   Erotica      NaN     $5.00  2014-08-10      Worldwide       Worldwide
# 936   Erotica      NaN     $5.00  2014-08-10      Worldwide       Worldwide
# 937   Erotica      NaN     $5.00  2014-08-10      Worldwide       Worldwide
# 938   Erotica      NaN     $5.00  2014-08-10      Worldwide       Worldwide
# 939   Erotica      NaN     $5.00  2014-08-10      Worldwide       Worldwide
# 940   Erotica      NaN     $5.00  2014-08-10      Worldwide       Worldwide
#
#                     vendor                        cat
# 0     NODDING4YOU  4.4  25          [Opioids, Heroin]
# 1     NODDING4YOU  4.4  25          [Opioids, Heroin]
# 2     NODDING4YOU  4.4  25          [Opioids, Heroin]
# 3     NODDING4YOU  4.4  25          [Opioids, Heroin]
# 4          alchemy  5.0  3          [Opioids, Heroin]
# 5          alchemy  5.0  3          [Opioids, Heroin]
# 6          alchemy  5.0  3          [Opioids, Heroin]
# 7          alchemy  5.0  3          [Opioids, Heroin]
# 8          alchemy  5.0  3          [Opioids, Heroin]
# 9          alchemy  5.0  3          [Opioids, Heroin]
# 10     NotoSeller  5.0  51   [Digital Goods, Erotica]
# 11     NotoSeller  5.0  51   [Digital Goods, Erotica]
# 12     NotoSeller  5.0  51   [Digital Goods, Erotica]
# 13     NotoSeller  5.0  51   [Digital Goods, Erotica]
# 14     NotoSeller  5.0  51   [Digital Goods, Erotica]
# 15     NotoSeller  5.0  51   [Digital Goods, Erotica]
# 16     NotoSeller  5.0  51   [Digital Goods, Erotica]
# 17     NotoSeller  5.0  51   [Digital Goods, Erotica]
# 18     NotoSeller  5.0  51   [Digital Goods, Erotica]
# 19     NotoSeller  5.0  51   [Digital Goods, Erotica]
# 20          sereal  5.0  2  [Digital Goods, Software]
# 21         Aracay  4.9  38  [Digital Goods, Software]
# 22         Aracay  4.9  38  [Digital Goods, Software]
# 23         Aracay  4.9  38  [Digital Goods, Software]
# 24         andevak  2.5  7  [Digital Goods, Software]
# 25          sereal  5.0  2  [Digital Goods, Software]
# 26          sereal  5.0  2  [Digital Goods, Software]
# 27          sereal  5.0  2  [Digital Goods, Software]
# 28     toysoldiers  5.0  2  [Digital Goods, Software]
# 29       MagicHat  4.3  40  [Digital Goods, Software]
# ..                     ...                        ...
# 911         Roquet  5.0  1      [Stimulants, Cocaine]
# 912         Roquet  5.0  1      [Stimulants, Cocaine]
# 913         Roquet  5.0  1      [Stimulants, Cocaine]
# 914         Roquet  5.0  1      [Stimulants, Cocaine]
# 915   namedeclined  5.0  4      [Stimulants, Cocaine]
# 916   namedeclined  5.0  4      [Stimulants, Cocaine]
# 917   namedeclined  5.0  4      [Stimulants, Cocaine]
# 918   namedeclined  5.0  4      [Stimulants, Cocaine]
# 919   namedeclined  5.0  4      [Stimulants, Cocaine]
# 920   namedeclined  5.0  4      [Stimulants, Cocaine]
# 921    QualityWeed  5.0  0           [Cannabis, Weed]
# 922    QualityWeed  5.0  0           [Cannabis, Weed]
# 923  VikingShrooms  5.0  0           [Cannabis, Weed]
# 924  RogerTheAlien  5.0  9           [Cannabis, Weed]
# 925  RogerTheAlien  5.0  9           [Cannabis, Weed]
# 926  RogerTheAlien  5.0  9           [Cannabis, Weed]
# 927  RogerTheAlien  5.0  9           [Cannabis, Weed]
# 928  RogerTheAlien  5.0  9           [Cannabis, Weed]
# 929         Roquet  5.0  1           [Cannabis, Weed]
# 930         Roquet  5.0  1           [Cannabis, Weed]
# 931    NotoSeller  5.0  11   [Digital Goods, Erotica]
# 932    NotoSeller  5.0  11   [Digital Goods, Erotica]
# 933    NotoSeller  5.0  11   [Digital Goods, Erotica]
# 934    NotoSeller  5.0  11   [Digital Goods, Erotica]
# 935    NotoSeller  5.0  11   [Digital Goods, Erotica]
# 936    NotoSeller  5.0  11   [Digital Goods, Erotica]
# 937    NotoSeller  5.0  11   [Digital Goods, Erotica]
# 938    NotoSeller  5.0  11   [Digital Goods, Erotica]
# 939    NotoSeller  5.0  11   [Digital Goods, Erotica]
# 940    NotoSeller  5.0  11   [Digital Goods, Erotica]
#
# [17353 rows x 8 columns]

# %%
def postprocess(df):
    """
    standardized postprocessing
    """
    #normalize
    df['category'] = df['category'].map(lambda x:x.lower())
    
    #discard meta-categories
    df = df[df['category'].map(lambda x:x not in META_CATS)]
    logger.info(df.shape)
    
    #discard non-string categories
    def isfloat(value):
        try:
            float(value)
            return True
        except ValueError:
            return False
    df = df[df['category'].map(lambda x:not isfloat(x))]
    
    return df

# %%
# cn = load_cloudnine()
# cn = postprocess(cn)
# cn.to_csv('/home/aahu/Dropbox/black-market-recommender-systems/data/cloudnine.tsv',sep='\t',index=False)

# ag = load_agora()
# ag = postprocess(ag)
# ag.to_csv('/home/aahu/Dropbox/black-market-recommender-systems/data/agora.tsv',sep='\t',index=False)

#pa = load_pandora()
#pa = postprocess(pa)
#pa.to_csv('/home/aahu/Dropbox/black-market-recommender-systems/data/pandora.tsv',sep='\t',index=False)

hy = load_hydra()
hy = postprocess(hy)
hy.to_csv('/home/aahu/Dropbox/black-market-recommender-systems/data/hydra.tsv',sep='\t',index=False)
# Out:
# May 17 00:04:28 INFO   Index(['cat', 'listing', 'price', 'quantity_available', 'quantity_sold', 'scrape_date', 'ships_from', 'ships_to', 'vendor'], dtype='object')
# INFO:__main__:Index(['cat', 'listing', 'price', 'quantity_available', 'quantity_sold', 'scrape_date', 'ships_from', 'ships_to', 'vendor'], dtype='object')
# May 17 00:04:28 INFO   (92407, 9)
# INFO:__main__:(92407, 9)
# May 17 00:04:29 INFO   (85559, 10)
# INFO:__main__:(85559, 10)
# May 17 00:04:36 INFO   Index(['category', 'listing', 'price_btc', 'scrape_date', 'ships_from', 'ships_to', 'vendor'], dtype='object')
# INFO:__main__:Index(['category', 'listing', 'price_btc', 'scrape_date', 'ships_from', 'ships_to', 'vendor'], dtype='object')
# May 17 00:04:36 INFO   (1773538, 7)
# INFO:__main__:(1773538, 7)
# May 17 00:04:38 INFO   (1639069, 7)
# INFO:__main__:(1639069, 7)
# May 17 00:05:30 INFO   Index(['category', 'item', 'price_usd', 'scrape_date', 'ships_from', 'ships_to', 'vendor'], dtype='object')
# INFO:__main__:Index(['category', 'item', 'price_usd', 'scrape_date', 'ships_from', 'ships_to', 'vendor'], dtype='object')
# May 17 00:05:30 INFO   (1422936, 7)
# INFO:__main__:(1422936, 7)
# May 17 00:05:31 INFO   (764335, 7)
# INFO:__main__:(764335, 7)
